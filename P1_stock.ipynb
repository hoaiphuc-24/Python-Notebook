# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
stock_data=pd.read_csv('D:/New folder/Semester 3/ADY301m/file csv/NFLX_stock.csv')
pd.set_option('display.width', 1000)
print(stock_data.head())
# Out:
#        Date        Open        High         Low       Close   Adj Close      Volume
# 0  2/5/2018  262.000000  267.899994  250.029999  254.259995  254.259995  11896100.0
# 1  2/6/2018  247.699997  266.700012  245.000000  265.720001  265.720001  12595800.0
# 2  2/7/2018  266.579987  272.450012  264.329987  264.559998  264.559998   8981500.0
# 3  2/8/2018  267.079987  267.619995  250.000000  250.100006  250.100006   9306700.0
# 4  2/9/2018  253.850006  255.800003  236.110001  249.470001  249.470001  16906900.0

# %%
stock_data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
#check null value
stock_data.isnull().sum()
# Out:
# Date          0
# Open         21
# High          5
# Low           9
# Close         5
# Adj Close     2
# Volume       10
# dtype: int64

# %%
#Chuyển đổi cột 'Date' thành định dạng datetime
stock_data['Date'] = pd.to_datetime(stock_data['Date'])

print(stock_data.head())
# Out:
#         Date        Open        High         Low       Close   Adj Close      Volume
# 0 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995  11896100.0
# 1 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001  12595800.0
# 2 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998   8981500.0
# 3 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006   9306700.0
# 4 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001  16906900.0

# %%
#vẽ biểu đồ
plt.figure(figsize=(10, 6))
plt.plot(stock_data.index, stock_data['Close'], label='Close Price', color='blue')
plt.title('Stock Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.show()
